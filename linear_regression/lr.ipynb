# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# in this project, I want to create a model,for estimation of the price of the house
#
# lets go!!

# %% [markdown]
# lets import famous libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
#let's import our fucking data

data = pd.read_csv("../dataset/1632300362534233.csv")

# %%
data.shape
# Out:
# (3479, 8)

# %%
data.head(3)
# Out:
#   Area  Room  Parking  Warehouse  Elevator  Address         Price  Price(USD)
# 0   63     1     True       True      True  Shahran  1.850000e+09    61666.67
# 1   60     1     True       True      True  Shahran  1.850000e+09    61666.67
# 2   79     2     True       True      True   Pardis  5.500000e+08    18333.33

# %%
data.describe()
# Out:
#               Room         Price    Price(USD)
# count  3479.000000  3.479000e+03  3.479000e+03
# mean      2.079908  5.359023e+09  1.786341e+05
# std       0.758275  8.099935e+09  2.699978e+05
# min       0.000000  3.600000e+06  1.200000e+02
# 25%       2.000000  1.418250e+09  4.727500e+04
# 50%       2.000000  2.900000e+09  9.666667e+04
# 75%       2.000000  6.000000e+09  2.000000e+05
# max       5.000000  9.240000e+10  3.080000e+06

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3479 entries, 0 to 3478
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Area        3479 non-null   object
#  1   Room        3479 non-null   int64
#  2   Parking     3479 non-null   bool
#  3   Warehouse   3479 non-null   bool
#  4   Elevator    3479 non-null   bool
#  5   Address     3456 non-null   object
#  6   Price       3479 non-null   float64
#  7   Price(USD)  3479 non-null   float64
# dtypes: bool(3), float64(2), int64(1), object(2)
# memory usage: 146.2+ KB

# %%
data.Address
# Out:
# 0                  Shahran
# 1                  Shahran
# 2                   Pardis
# 3            Shahrake Qods
# 4           Shahrake Gharb
#                ...
# 3474    Southern Janatabad
# 3475              Niavaran
# 3476                Parand
# 3477                Dorous
# 3478                Parand
# Name: Address, Length: 3479, dtype: object

# %%
data["Address"].value_counts()
# Out:
# Punak                     161
# Pardis                    146
# West Ferdows Boulevard    145
# Gheitarieh                141
# Shahran                   130
#                          ...
# Chardangeh                  1
# Mehrabad                    1
# Pakdasht KhatunAbad         1
# Kazemabad                   1
# Yakhchiabad                 1
# Name: Address, Length: 192, dtype: int64

# %%
print(data["Area"].dtype)
data["Area"]
# Out:
# object
# 0        63
# 1        60
# 2        79
# 3        95
# 4       123
#        ...
# 3474     86
# 3475     83
# 3476     75
# 3477    105
# 3478     82
# Name: Area, Length: 3479, dtype: object

# %% [markdown]
# first,we should drop all rows,that have empty values

# %%
data = data.dropna()

# %%
data.shape
# Out:
# (3456, 8)

# %%
for i in data["Area"]:
    print(type(i))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# ...

# %%
data = data[~data["Area"].str.contains(",",na=False)]

# %%
for i in data["Area"]:
    if "," in i:
        print(i)

# %% [markdown]
# no,we have ommited all irrelevant values
#
# let's go and convert them to integers

# %%
data["Area"] = data["Area"].astype("Int64")
# Out:
# /tmp/ipykernel_6305/3952025737.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Area"] = data["Area"].astype("Int64")

# %%
for i in data["Area"]:
    print(type(i))
# Out:
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# ...

# %%
data.columns
# Out:
# Index(['Area', 'Room', 'Parking', 'Warehouse', 'Elevator', 'Address', 'Price',
#        'Price(USD)'],
#       dtype='object')

# %%
data.corr()
# Out:
# /tmp/ipykernel_6305/2627137660.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                 Area      Room   Parking  Warehouse  Elevator     Price  \
# Area        1.000000  0.672955  0.197890   0.076161  0.051473  0.722611
# Room        0.672955  1.000000  0.274425   0.129649  0.180380  0.567872
# Parking     0.197890  0.274425  1.000000   0.431925  0.430213  0.191221
# Warehouse   0.076161  0.129649  0.431925   1.000000  0.202708  0.109676
# Elevator    0.051473  0.180380  0.430213   0.202708  1.000000  0.111745
# Price       0.722611  0.567872  0.191221   0.109676  0.111745  1.000000
# Price(USD)  0.722611  0.567872  0.191221   0.109676  0.111745  1.000000
#
#             Price(USD)
# Area          0.722611
# Room          0.567872
# Parking       0.191221
# Warehouse     0.109676
# ...

# %% [markdown]
# bow, i want to use linear regression for this project
#
# first i won't use address feature to see if it has high impact

# %%
phase0_data = data.drop(columns=["Address","Price"])

# %%
phase0_data
# Out:
#       Area  Room  Parking  Warehouse  Elevator  Price(USD)
# 0       63     1     True       True      True    61666.67
# 1       60     1     True       True      True    61666.67
# 2       79     2     True       True      True    18333.33
# 3       95     2     True       True      True    30083.33
# 4      123     2     True       True      True   233333.33
# ...    ...   ...      ...        ...       ...         ...
# 3474    86     2     True       True      True   116666.67
# 3475    83     2     True       True      True   226666.67
# 3476    75     2    False      False     False    12166.67
# 3477   105     2     True       True      True   186666.67
# 3478    82     2    False       True      True    12000.00
#
# [3450 rows x 6 columns]

# %%
phase0_train,phase0_test = train_test_split(phase0_data,random_state=0)

# %%
phase0_train_x = phase0_train.drop(columns=["Price(USD)"])
phase0_train_y = phase0_train["Price(USD)"]

phase0_test_x = phase0_test.drop(columns=["Price(USD)"])
phase0_test_y = phase0_test["Price(USD)"]

# %%
lr = LinearRegression()
lr.fit(phase0_train_x,phase0_train_y)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score


predicted = lr.predict(phase0_test_x)

print("this models r2score is:{}".format(r2_score(phase0_test_y,predicted)))
# Out:
# this models r2score is:0.6100117783743703

# %% [markdown]
# to be honest,i dont think it is good,lets try tweaking tha dataset

# %% [markdown]
# we should invert area feature to integer in this dataset
#
# we should write a function for that

# %%
for num in data["Area"]:
    if("," in num):
        num = num.replace(",","")
